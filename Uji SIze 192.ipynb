# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import PIL
import tensorflow as tf
import time
from PIL import Image
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from skimage import io

# %% [markdown]
# # Data Train

# %%
train = '192x192/train'
train
# Out:
# '192x192/train'

# %%
import pathlib
train_dir = pathlib.Path(train)
train_dir
# Out:
# WindowsPath('192x192/train')

# %%
image_count = (
    len(list(train_dir.glob('*/*.jpg'))) +
    len(list(train_dir.glob('*/*.png'))) +
    len(list(train_dir.glob('*/*.jpeg')))
)
print(image_count)
# Out:
# 12012

# %%
train_image_dict = {
    'camera': list(train_dir.glob('camera/*')),
    'crt': list(train_dir.glob('crt/*')),
    'handphone': list(train_dir.glob('handphone/*')),
    'keyboard': list(train_dir.glob('keyboard/*')),
    'kulkas': list(train_dir.glob('kulkas/*')),
    'laptop': list(train_dir.glob('laptop/*')),
    'mesin cuci': list(train_dir.glob('mesin cuci/*')),
    'microwave': list(train_dir.glob('microwave/*')),
    'mouse': list(train_dir.glob('mouse/*')),
    'printer': list(train_dir.glob('printer/*')),
    'pv panel': list(train_dir.glob('pv panel/*')),
    'smartwatch': list(train_dir.glob('smartwatch/*')),
    'monitor flat': list(train_dir.glob('monitor flat/*')),
}

# %%
train_labels_dict = {
    'camera': 0,
    'crt': 1,
    'handphone': 2,
    'keyboard': 3,
    'kulkas': 4,
    'laptop': 5,
    'mesin cuci': 6,
    'microwave': 7,
    'mouse': 8,
    'printer': 9,
    'pv panel': 10,
    'smartwatch':11,
    'monitor flat':12
}

# %%
X, y, paths = [], [], []

for train_name, images in train_image_dict.items():
    for image in images:
        img = io.imread(image)
        X.append(img)
        y.append(train_labels_dict[train_name])
        paths.append(str(image))

# %% [markdown]
# # Data Validation

# %%
val = '192x192/val'
val
# Out:
# '192x192/val'

# %%
import pathlib
val_dir = pathlib.Path(val)
val_dir
# Out:
# WindowsPath('192x192/val')

# %%
image_count = (
    len(list(val_dir.glob('*/*.jpg'))) +
    len(list(val_dir.glob('*/*.png'))) +
    len(list(val_dir.glob('*/*.jpeg')))
)
print(image_count)
# Out:
# 2574

# %%
val_image_dict = {
    'camera': list(val_dir.glob('camera/*')),
    'crt': list(val_dir.glob('crt/*')),
    'handphone': list(val_dir.glob('handphone/*')),
    'keyboard': list(val_dir.glob('keyboard/*')),
    'kulkas': list(val_dir.glob('kulkas/*')),
    'laptop': list(val_dir.glob('laptop/*')),
    'mesin cuci': list(val_dir.glob('mesin cuci/*')),
    'microwave': list(val_dir.glob('microwave/*')),
    'mouse': list(val_dir.glob('mouse/*')),
    'printer': list(val_dir.glob('printer/*')),
    'pv panel': list(val_dir.glob('pv panel/*')),
    'smartwatch': list(val_dir.glob('smartwatch/*')),
    'monitor flat': list(val_dir.glob('monitor flat/*')),
}

# %%
val_labels_dict = {
    'camera': 0,
    'crt': 1,
    'handphone': 2,
    'keyboard': 3,
    'kulkas': 4,
    'laptop': 5,
    'mesin cuci': 6,
    'microwave': 7,
    'mouse': 8,
    'printer': 9,
    'pv panel': 10,
    'smartwatch':11,
    'monitor flat':12
}

# %%
X_val, y_val, paths_val = [], [], []

for val_name, images in val_image_dict.items():
    for image in images:
        img = io.imread(image)
        X_val.append(img)
        y_val.append(val_labels_dict[val_name])
        paths_val.append(str(image))

# %% [markdown]
# # Build Model

# %%
from tensorflow.keras.applications import ResNet50
base_model = ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape = (192,192,3)
)

for layer in base_model.layers:
    layer.trainable = False

# %%
from tensorflow.keras import models, layers

model = models.Sequential([
    layers.Input(shape=(192,192,3)),
    layers.Rescaling(1./255),
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(13, activation='softmax')  # jumlah class
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 192, 192, 3)       0
#
#  resnet50 (Functional)       (None, 6, 6, 2048)        23587712
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 13)                26637
#
# =================================================================
# Total params: 23,614,349
# Trainable params: 26,637
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
X = np.array(X)
y = np.array(y)
X_val = np.array(X_val)
y_val = np.array(y_val)

# %%
start = time.time()
history = model.fit(
    X,
    y,
    epochs=15,
    validation_data=(X_val, y_val),
    verbose=1,
    shuffle = True
)
end = time.time()
# Out:
# Epoch 1/15
# 376/376 [==============================] - 47s 78ms/step - loss: 2.3952 - accuracy: 0.2000 - val_loss: 2.2447 - val_accuracy: 0.2525
# Epoch 2/15
# 376/376 [==============================] - 26s 69ms/step - loss: 2.1876 - accuracy: 0.2943 - val_loss: 2.1204 - val_accuracy: 0.3139
# Epoch 3/15
# 376/376 [==============================] - 26s 69ms/step - loss: 2.0937 - accuracy: 0.3268 - val_loss: 2.0445 - val_accuracy: 0.3528
# Epoch 4/15
# 376/376 [==============================] - 26s 69ms/step - loss: 2.0260 - accuracy: 0.3467 - val_loss: 1.9739 - val_accuracy: 0.3792
# Epoch 5/15
# 376/376 [==============================] - 26s 69ms/step - loss: 1.9755 - accuracy: 0.3601 - val_loss: 1.9293 - val_accuracy: 0.4106
# Epoch 6/15
# 376/376 [==============================] - 26s 69ms/step - loss: 1.9320 - accuracy: 0.3857 - val_loss: 1.8985 - val_accuracy: 0.4099
# Epoch 7/15
# 376/376 [==============================] - 26s 69ms/step - loss: 1.8986 - accuracy: 0.3886 - val_loss: 1.8590 - val_accuracy: 0.4289
# Epoch 8/15
# 376/376 [==============================] - 26s 68ms/step - loss: 1.8706 - accuracy: 0.3977 - val_loss: 1.8398 - val_accuracy: 0.4211
# Epoch 9/15
# 376/376 [==============================] - 27s 72ms/step - loss: 1.8423 - accuracy: 0.4078 - val_loss: 1.8293 - val_accuracy: 0.4375
# Epoch 10/15
# 376/376 [==============================] - 26s 69ms/step - loss: 1.8206 - accuracy: 0.4212 - val_loss: 1.7928 - val_accuracy: 0.4429
# Epoch 11/15
# 376/376 [==============================] - 27s 72ms/step - loss: 1.7993 - accuracy: 0.4226 - val_loss: 1.7778 - val_accuracy: 0.4421
# Epoch 12/15
# 376/376 [==============================] - 26s 68ms/step - loss: 1.7778 - accuracy: 0.4322 - val_loss: 1.7724 - val_accuracy: 0.4441
# Epoch 13/15
# 376/376 [==============================] - 26s 69ms/step - loss: 1.7617 - accuracy: 0.4397 - val_loss: 1.7495 - val_accuracy: 0.4487
# Epoch 14/15
# 376/376 [==============================] - 26s 69ms/step - loss: 1.7460 - accuracy: 0.4453 - val_loss: 1.7295 - val_accuracy: 0.4604
# Epoch 15/15
# 376/376 [==============================] - 26s 68ms/step - loss: 1.7286 - accuracy: 0.4522 - val_loss: 1.7203 - val_accuracy: 0.4631

# %%
waktu_training = end-start
minutes = int(waktu_training // 60)  # Bagian menit
seconds = waktu_training % 60
print(f"{waktu_training} detik = {minutes} menit {seconds:.2f} detik")
# Out:
# 452.0729031562805 detik = 7 menit 32.07 detik

# %% [markdown]
# # Grafik

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(history.history['accuracy']) + 1)

# Akurasi
plt.plot(epochs, history.history['accuracy'], label='Train Accuracy')
plt.plot(epochs, history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Loss
plt.plot(epochs, history.history['loss'], label='Train Loss')
plt.plot(epochs, history.history['val_loss'], label='Val Loss')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Data Test

# %%
test = '192x192/test'
test
# Out:
# '192x192/test'

# %%
import pathlib
test_dir = pathlib.Path(test)
test_dir
# Out:
# WindowsPath('192x192/test')

# %%
image_count = (
    len(list(test_dir.glob('*/*.jpg'))) +
    len(list(test_dir.glob('*/*.png'))) +
    len(list(test_dir.glob('*/*.jpeg')))
)
print(image_count)
# Out:
# 2574

# %%
test_image_dict = {
    'camera': list(test_dir.glob('camera/*')),
    'crt': list(test_dir.glob('crt/*')),
    'handphone': list(test_dir.glob('handphone/*')),
    'keyboard': list(test_dir.glob('keyboard/*')),
    'kulkas': list(test_dir.glob('kulkas/*')),
    'laptop': list(test_dir.glob('laptop/*')),
    'mesin cuci': list(test_dir.glob('mesin cuci/*')),
    'microwave': list(test_dir.glob('microwave/*')),
    'mouse': list(test_dir.glob('mouse/*')),
    'printer': list(test_dir.glob('printer/*')),
    'pv panel': list(test_dir.glob('pv panel/*')),
    'smartwatch': list(test_dir.glob('smartwatch/*')),
    'monitor flat': list(test_dir.glob('monitor flat/*')),
}

# %%
test_labels_dict = {
    'camera': 0,
    'crt': 1,
    'handphone': 2,
    'keyboard': 3,
    'kulkas': 4,
    'laptop': 5,
    'mesin cuci': 6,
    'microwave': 7,
    'mouse': 8,
    'printer': 9,
    'pv panel': 10,
    'smartwatch':11,
    'monitor flat':12
}

# %%
X_test, y_test, paths_test = [], [], []

for test_name, images in test_image_dict.items():
    for image in images:
        img = io.imread(image)
        X_test.append(img)
        y_test.append(test_labels_dict[test_name])
        paths_test.append(str(image))

# %%
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
model.evaluate(X_test, y_test)
# Out:
# 81/81 [==============================] - 5s 58ms/step - loss: 1.7344 - accuracy: 0.4421
# [1.7344478368759155, 0.4421134293079376]
